# %%
# Installing the required libraries 
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (3.8.4)
# Requirement already satisfied: pandas>=1.0.4 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays>=0.25 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (0.56)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from prophet) (6.4.4)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
# Importing required libraries and dependencies 
import pandas as pd
import datetime as dt 
import numpy as np
from prophet import Prophet 
import matplotlib.pyplot as plt

# %%
# File Path For CSV
file_path = "../Resources/Economy_Data.csv"

# %%
# Reading the Ecomonic Data file into a Pandas DataFrame 
economic_data = pd.read_csv(file_path, delimiter=";").dropna()

# Displaying the first five rows of the Data Frame
economic_data.head()
# Out:
#                                           SeriesName      SeriesCode  \
# 5   Adjusted net national income (constant 2010 US$)  NY.ADJ.NNTY.KD
# 7   Adjusted net national income (constant 2010 US$)  NY.ADJ.NNTY.KD
# 10        Adjusted net national income (current US$)  NY.ADJ.NNTY.CD
# 11        Adjusted net national income (current US$)  NY.ADJ.NNTY.CD
# 12        Adjusted net national income (current US$)  NY.ADJ.NNTY.CD
#
#    CountryName CountryCode    Year         Value
# 5       Brazil         BRA  1970.0  3.918974e+11
# 7        India         IND  1970.0  1.915335e+11
# 10      Brazil         BRA  1970.0  3.786021e+10
# 11       China         CHN  1970.0  8.525561e+10
# 12       India         IND  1970.0  5.776720e+10

# %%
# Filtering the data to only show the years 2009-2019 (We wanted to focus on the past 10 years and this was the most recent 10 year period)
filtered_economic_data = economic_data[(economic_data["Year"] >= 2009) & (economic_data["Year"] <=2019)]

# Displaying the first five rows of the filtered Data Frame  
filtered_economic_data.head()
# Out:
#                                            SeriesName         SeriesCode  \
# 67470  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67471  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67472  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67473  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67474  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
#
#               CountryName CountryCode    Year      Value
# 67470              Brazil         BRA  2009.0   5.421578
# 67471               China         CHN  2009.0  13.262097
# 67472               India         IND  2009.0   9.589941
# 67473  Russian Federation         RUS  2009.0 -17.518426
# 67474        South Africa         ZAF  2009.0   4.761918

# %%
# Filtering The Data for Adjusted Net National Income
net_national_income_all = filtered_economic_data[filtered_economic_data["SeriesName"].str.contains("Adjusted net national income", case=False)]

# Viewing the first five rows of the net_national_income_all Data Frame 
net_national_income_all.head()
# Out:
#                                            SeriesName         SeriesCode  \
# 67470  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67471  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67472  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67473  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
# 67474  Adjusted net national income (annual % growth)  NY.ADJ.NNTY.KD.ZG
#
#               CountryName CountryCode    Year      Value
# 67470              Brazil         BRA  2009.0   5.421578
# 67471               China         CHN  2009.0  13.262097
# 67472               India         IND  2009.0   9.589941
# 67473  Russian Federation         RUS  2009.0 -17.518426
# 67474        South Africa         ZAF  2009.0   4.761918

# %%
# Grouping by "CountryName" and "Year" then calculating the mean for annual % growth 
group_net_national_income = net_national_income_all.groupby(["CountryName", "Year"])["Value"].mean().reset_index()

# Displaying the first five rows of the filtered Data Frame 
group_net_national_income.head()
# Out:
#   CountryName    Year         Value
# 0      Brazil  2009.0  5.249900e+11
# 1      Brazil  2010.0  6.095448e+11
# 2      Brazil  2011.0  6.824218e+11
# 3      Brazil  2012.0  6.709171e+11
# 4      Brazil  2013.0  6.915997e+11

# %%
# Creating a line plot to show the Adjusted net national income
group_net_national_income.pivot(index="Year", columns="CountryName", values="Value").plot(kind="line", figsize=(8,6))

# Setting titles and labels
plt.title("Adjusted net national income (annual percentage growth)")
plt.xlabel("Year")
plt.ylabel("Net National Income (Percentage Growth)")
plt.show()

# %%
# Grouping by "CountryName" and "Year" then calculating the sum for annual % growth 
grouped_net_income_dollar_amount = net_national_income_all.groupby(["CountryName", "Year",])["Value"].sum().reset_index()

# Creating a bar graph to show the Adjusted net national income in dollar amount 
grouped_net_income_dollar_amount.pivot(index="Year", columns="CountryName", values="Value").plot(kind="bar", figsize=(8,6))

# Setting titles and labels
plt.title("Adjusted net national income (Trillions USD$)")
plt.xlabel("Year")
plt.ylabel("Net National Income (Trillions USD$)")
plt.show()

# %%
# Filtering The Data for Adjusted Net National Income Per Capita 
net_national_income_per_capita = filtered_economic_data[filtered_economic_data["SeriesName"].str.contains("Adjusted net national income per capita (current US$)", case=False, regex=False)]

# Displaying the first few rows of Adjusted Net National Income Per Capita Data Frame
net_national_income_per_capita.head()
# Out:
#                                               SeriesName         SeriesCode  \
# 67495  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 67496  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 67497  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 67498  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 67499  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
#
#               CountryName CountryCode    Year        Value
# 67495              Brazil         BRA  2009.0  7274.154180
# 67496               China         CHN  2009.0  2910.973447
# 67497               India         IND  2009.0   957.908415
# 67498  Russian Federation         RUS  2009.0  6679.046482
# 67499        South Africa         ZAF  2009.0  4738.759732

# %%
# Grouping by "CountryName" and "Year" then calculating the mean for annual % growth 
group_net_national_income_per_capita = net_national_income_per_capita.groupby(["CountryName", "Year"])["Value"].mean().reset_index()

# Displaying the first five rows of the filtered Data Frame 
group_net_national_income_per_capita.head()
# Out:
#   CountryName    Year         Value
# 0      Brazil  2009.0   7274.154180
# 1      Brazil  2010.0   9343.418936
# 2      Brazil  2011.0  10986.503157
# 3      Brazil  2012.0  10301.753909
# 4      Brazil  2013.0  10407.092896

# %%
# Creating a line plot to show the Adjusted net national income per capita
group_net_national_income_per_capita.pivot(index="Year", columns="CountryName", values="Value").plot(kind="line", figsize=(8,6))

# Setting titles and labels
plt.title("Adjusted Net National Income per Capita (2009-2019)")
plt.xlabel("Year")
plt.ylabel("Net National Income per Capita (current US$)")
plt.legend(title="Country", loc="upper right")
plt.show()

# %%
# Creating a bar graph to show the Adjusted net national income per capita
group_net_national_income_per_capita.pivot(index="Year", columns="CountryName", values="Value").plot(kind="bar", figsize=(8,6))

# Setting titles and labels
plt.title("Adjusted Net National Income per Capita (2009-2019)")
plt.xlabel("Year")
plt.ylabel("Net National Income per Capita (current US$)")
plt.legend(title="Country", loc="upper right", fontsize="small")
plt.show()

# %%
# Filtering The Data for Agriculture, forestry, and fishing, value added
agriculture_forestry_fishing = filtered_economic_data[filtered_economic_data["SeriesName"].str.contains('Agriculture, forestry, and fishing, value added (annual % growth)', case=False, regex=False)]

agriculture_forestry_fishing.head()
# Out:
#                                               SeriesName         SeriesCode  \
# 67615  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 67616  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 67617  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 67618  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 67619  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
#
#               CountryName CountryCode    Year     Value
# 67615              Brazil         BRA  2009.0 -3.728680
# 67616               China         CHN  2009.0  3.995766
# 67617               India         IND  2009.0 -0.880233
# 67618  Russian Federation         RUS  2009.0  1.680506
# 67619        South Africa         ZAF  2009.0 -1.892282

# %%
# Grouping by "CountryName" and "Year" then calculating the mean for annual % growth for agriculture 
group_agriculture_forestry_fishing = agriculture_forestry_fishing.groupby(["CountryName", "Year"])["Value"].mean().reset_index()

# Displaying the first five rows of the filtered Data Frame 
group_agriculture_forestry_fishing.head()
# Out:
#   CountryName    Year     Value
# 0      Brazil  2009.0 -3.728680
# 1      Brazil  2010.0  6.696942
# 2      Brazil  2011.0  5.638646
# 3      Brazil  2012.0 -3.082242
# 4      Brazil  2013.0  8.361444

# %%
# Creating a line plot to show the data for Agriculture, forestry, and fishing, value added
group_agriculture_forestry_fishing.pivot(index="Year", columns="CountryName", values="Value").plot(kind="line", figsize=(8,6))

# Setting titles and labels
plt.title("Agriculture, forestry, and fishing, value added (annual % growth)")
plt.xlabel("Year")
plt.ylabel("Agriculture, forestry, and fishing, value added")
plt.legend(title="Country", loc="lower right")
plt.show()

# %%
# Creating a bar graph to show the data for Agriculture, forestry, and fishing, value added (annual % growth)
group_agriculture_forestry_fishing.pivot(index="Year", columns="CountryName", values="Value").plot(kind="bar", figsize=(8,6))

# Setting titles and labels
plt.title("Agriculture, forestry, and fishing, annual % growth (2009-2019)")
plt.xlabel("Year")
plt.ylabel("Agriculture, forestry, and fishing, annual %")
plt.legend(title="Country", loc="upper left")
plt.show()

# %%
# Filtering The Data for GDP (constant 2010 US$)
gdp = filtered_economic_data[filtered_economic_data["SeriesName"].str.contains("GDP (constant 2010 US$)", case=False, regex=False)]

# Showing the first five results of the Data Frame 
gdp.head()
# Out:
#                     SeriesName      SeriesCode         CountryName  \
# 67890  GDP (constant 2010 US$)  NY.GDP.MKTP.KD              Brazil
# 67891  GDP (constant 2010 US$)  NY.GDP.MKTP.KD               China
# 67892  GDP (constant 2010 US$)  NY.GDP.MKTP.KD               India
# 67893  GDP (constant 2010 US$)  NY.GDP.MKTP.KD  Russian Federation
# 67894  GDP (constant 2010 US$)  NY.GDP.MKTP.KD        South Africa
#
#       CountryCode    Year         Value
# 67890         BRA  2009.0  2.054225e+12
# 67891         CHN  2009.0  5.501968e+12
# 67892         IND  2009.0  1.544380e+12
# 67893         RUS  2009.0  1.459251e+12
# 67894         ZAF  2009.0  3.642764e+11

# %%
groupby_gdp = gdp.groupby(["CountryName", "Year"])["Value"].sum().reset_index()

groupby_gdp.head()
# Out:
#   CountryName    Year         Value
# 0      Brazil  2009.0  2.054225e+12
# 1      Brazil  2010.0  2.208872e+12
# 2      Brazil  2011.0  2.296662e+12
# 3      Brazil  2012.0  2.340784e+12
# 4      Brazil  2013.0  2.411121e+12

# %%
groupby_gdp.pivot(index="Year", columns="CountryName", values="Value").plot(kind="line", figsize=(8,6))

# Setting titles and labels
plt.title("GDP")
plt.xlabel("Year")
plt.ylabel("GDP (constant 2010 US$ in trillions)")
plt.legend(title="Country", loc="upper left")
plt.show()

# %%
groupby_gdp.pivot(index="Year", columns="CountryName", values="Value").plot(kind="bar", figsize=(8,6))

# Setting titles and labels
plt.title("GDP")
plt.xlabel("Year")
plt.ylabel("GDP (constant 2010 US$ in trillions)")
plt.legend(title="Country", loc="upper left")
plt.show()
